# %% [markdown]
# # importing csv and json files

# %%
import pandas as pd

# %% [markdown]
# **import a csv file**

# %%
df = pd.read_csv("students_large_dataset.csv")
print(df)
# Out:
#      student_id     name department  semester  cgpa  attendance_percent
# 0          1001   Karima        ICE         5  2.49                  68
# 1          1002   Karima         CE         2  3.18                  62
# 2          1003   Arafat        ICE         4  2.47                  98
# 3          1004   Arafat         CE         4  3.43                  94
# 4          1005  Sumaiya        CSE         8  3.18                  60
# ..          ...      ...        ...       ...   ...                 ...
# 175        1176    Hasan        CSE         5  3.10                  95
# 176        1177  Sumaiya        ICE         4  3.98                  67
# 177        1178    Imran        ICE         3  3.00                  78
# 178        1179    Rakib        EEE         7  3.67                  90
# 179        1180    Hasan         ME         3  2.77                  98
#
# [180 rows x 6 columns]

# %%
# if we want to print all the items of the dataset, we have to use the following code
df = pd.read_csv("students_large_dataset.csv")
print(df.to_string()) # its will print entire dataset

# %% [markdown]
# **Lets import a json file**

# %%
df = pd.read_json("students_large_dataset.json")
print(df)
# Out:
#      student_id     name department  semester  cgpa  attendance_percent
# 0          1001   Karima        ICE         5  2.49                  68
# 1          1002   Karima         CE         2  3.18                  62
# 2          1003   Arafat        ICE         4  2.47                  98
# 3          1004   Arafat         CE         4  3.43                  94
# 4          1005  Sumaiya        CSE         8  3.18                  60
# ..          ...      ...        ...       ...   ...                 ...
# 175        1176    Hasan        CSE         5  3.10                  95
# 176        1177  Sumaiya        ICE         4  3.98                  67
# 177        1178    Imran        ICE         3  3.00                  78
# 178        1179    Rakib        EEE         7  3.67                  90
# 179        1180    Hasan         ME         3  2.77                  98
#
# [180 rows x 6 columns]

# %%
# if we wnat to print all the items of the data frame
print(df.to_string())

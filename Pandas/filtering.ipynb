# %%
import pandas as pd

# %%
df = pd.read_csv("students_large_dataset.csv")

high_cg = df[df["cgpa"] >= 3.5]
print(high_cg.head())
print()

good_students = df[(df["cgpa"] >= 3.5) & (df["attendance_percent"] >= 80)]
print(good_students.head()) # head() Display the first 5 elements
# Out:
#     student_id    name department  semester  cgpa  attendance_percent
# 7         1008  Nayeem         CE         5  3.61                  89
# 10        1011   Hasan        EEE         2  3.71                  66
# 15        1016   Anika        CSE         6  3.69                  63
# 21        1022   Rakib         ME         2  3.51                  67
# 24        1025  Arafat        ICE         5  3.54                  81
#
#     student_id     name department  semester  cgpa  attendance_percent
# 7         1008   Nayeem         CE         5  3.61                  89
# 24        1025   Arafat        ICE         5  3.54                  81
# 31        1032    Rahim         ME         2  3.96                  94
# 33        1034    Rifat         CE         7  3.93                  94
# 34        1035  Farzana        EEE         7  3.99                  83

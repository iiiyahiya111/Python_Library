# %%
import pandas as pd

# %%
df = pd.read_csv("students_large_dataset.csv")

print(df.head())
print()
print(df.mean(numeric_only=True))
# Out:
#    student_id     name department  semester  cgpa  attendance_percent
# 0        1001   Karima        ICE         5  2.49                  68
# 1        1002   Karima         CE         2  3.18                  62
# 2        1003   Arafat        ICE         4  2.47                  98
# 3        1004   Arafat         CE         4  3.43                  94
# 4        1005  Sumaiya        CSE         8  3.18                  60
#
# student_id            1090.500000
# semester                 4.522222
# cgpa                     3.064722
# attendance_percent      80.916667
# dtype: float64

# %%
print(df.max(numeric_only=True))
# Out:
# student_id             1180
# name                  Tisha
# department               ME
# semester                  8
# cgpa                    4.0
# attendance_percent      100
# dtype: object

# %%
print(df.min(numeric_only=True))
# Out:
# student_id            1001.00
# semester                 1.00
# cgpa                     2.02
# attendance_percent      60.00
# dtype: float64

# %%
print(df.count())
# Out:
# student_id            180
# name                  180
# department            180
# semester              180
# cgpa                  180
# attendance_percent    180
# dtype: int64

# %% [markdown]
# **single column**

# %%
print(df["cgpa"].mean())
# Out:
# 3.064722222222222
